# %% [markdown]
# <h2>Introduction</h2>
#
# A travel agency is going offer its customers recommendation to the locations (neighborhoods) for given cuisines in major neighborhoods in Seattle, WA area. The App will allow users select from a list of cuisines then recommend the top 3 neighborhoods where they can have the most choices.
#
# There are 91 neighborhoods in Seattle area. In this project, I implemented two features:
#
# - The customers can query the restaurants for a specified cuisine in the major Seattle neighborhoods, which have 'Seattle' in name.
# - The customers can query all restaurants (limit to 50 for demo purpose) in any one of Seattle neighborhood.

# %% [markdown]
# <h3>Import needed packages</h3>

# %%
import requests
import numpy as np
import pandas as pd
import random

# %%
# !pip install geopy
import geopy
from geopy.geocoders import Nominatim

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML
# Out:
# Requirement already satisfied: geopy in c:\users\weiminli\appdata\local\enthought\canopy\user\lib\site-packages (1.20.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\weiminli\appdata\local\enthought\canopy\user\lib\site-packages (from geopy) (1.50)
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support

# %% [markdown]
# <h2>Data Section</h2>
#
# - Collecting the Latitude and Longitude for all neighborhoods in Seattle, WA area.
# - Select the major neighborhood in Seatlle area.
# - Using Foursquare location data API to extract cuisine venues by food categories that will be used for each neighborhoods in Seattle area.
# - Select top neighborhoods (by ordering the displayed neighborhoods) where there are most choices of the chosen cuisine to be select from.

# %%
import bs4
from bs4 import BeautifulSoup

# %%
wikipage_seattle = requests.get('https://en.wikipedia.org/wiki/List_of_neighborhoods_in_Seattle')

soup = BeautifulSoup(wikipage_seattle.content, 'lxml')
tbl = soup.find(class_="wikitable sortable")

df = pd.read_html(str(tbl))[0]
#neighborhoods = [s + ', WA' for s in df.iloc[:,1].reset_index(drop=True).tolist()]
neighborhoods = df.iloc[1:,1].reset_index(drop=True).tolist()

neighborhoods
# Out:
# ['North Seattle',
#  'Broadview',
#  'Bitter Lake',
#  'North Beach / Blue Ridge',
#  'Crown Hill',
#  'Greenwood',
#  'Northgate',
#  'Haller Lake',
#  'Pinehurst',
#  'North College Park (Licton Springs)',
#  'Maple Leaf',
#  'Lake City',
#  'Cedar Park',
#  'Matthews Beach',
#  'Meadowbrook',
#  'Olympic Hills',
#  'Victory Heights',
#  'Wedgwood',
#  'View Ridge',
#  'Sand Point',
#  'Roosevelt',
#  'Ravenna',
#  'Bryant',
#  'Windermere',
#  'Hawthorne Hills',
#  'Laurelhurst',
#  'University District (U District)',
#  'University Village',
#  'Wallingford',
#  'Northlake',
#  'Green Lake',
#  'Fremont',
#  'Phinney Ridge',
#  'Ballard',
#  'West Woodland',
#  'Whittier Heights',
#  'Adams',
#  'Sunset Hill',
#  'Loyal Heights',
#  'Central Seattle',
#  'Magnolia',
#  'Lawton Park',
#  'Briarcliff',
#  'Southeast Magnolia',
#  'Interbay',
#  'Queen Anne',
#  'North Queen Anne',
#  'East Queen Anne',
#  'Lower Queen Anne',
#  'West Queen Anne',
#  'Capitol Hill',
#  'Portage Bay[95] / Roanoke',
#  'Broadway',
#  'Pike-Pine Corridor / Pike/Pine[97][98][99]',
#  'Montlake',
#  'Stevens',
#  'Interlaken',
#  'Madison Valley',
#  'Renton Hill',
#  'Madison Park',
#  'Broadmoor',
#  'Lake Union',
#  'South Lake Union, Seattle',
#  'Cascade, Seattle',
#  'Westlake',
#  'Eastlake',
#  'Downtown',
#  'Denny Triangle',
#  'Belltown',
#  'Pike-Market',
#  'Central Business District',
#  'First Hill',
#  'Pioneer Square',
#  'International District ("ID")',
#  'Yesler Terrace',
#  'Central Waterfront',
#  'West Edge[118][119]',
#  'Central Area[120] / Central District ("CD")',
#  'Mann',
#  'Minor',
#  'Cherry Hill & Squire Park',
#  'Atlantic',
#  'Judkins Park',
#  'Madrona',
#  'Madrona Valley',
#  'Harrison[120] / Denny-Blaine[120]',
#  'Washington Park',
#  'Leschi[120]',
#  'South End',
#  'Rainier Valley',
#  'Mount Baker',
#  'Columbia City',
#  'Hillman City',
#  'Brighton',
#  'Dunlap / Othello',
#  'Rainier Beach / Atlantic City Beach',
#  'Rainier View / Lakeridge',
#  'Seward Park',
#  'Lakewood',
#  'Beacon Hill',
#  'North Beacon Hill',
#  'Mid Beacon Hill (Maplewood)',
#  'Holly Park[144] / NewHolly[145]',
#  'South Beacon Hill[146] / Van Asselt',
#  'Industrial District',
#  'SoDo',
#  'Harbor Island',
#  'Georgetown',
#  'South Park',
#  'West Seattle',
#  'Alki Point',
#  'North Admiral[153] / Admiral District',
#  'Junction[154] / West Seattle Junction / Alaska Junction',
#  'Seaview[155] / Mee-Kwa-Mooks',
#  'Fairmount Park',
#  'Genesee',
#  'Gatewood',
#  'Fauntleroy',
#  'Arbor Heights',
#  'Delridge',
#  'North Delridge',
#  'Pigeon Point',
#  'Riverview',
#  'Highland Park',
#  'South Delridge',
#  'Roxhill',
#  'High Point']

# %% [markdown]
# <h3>The Major neighborhoods (the name contains 'Seattle') in Seattle area.</h3>

# %%
seattle_neighborhoods = pd.DataFrame(columns=['Neighborhood', 'Latitude', 'Longitude'])

geolocator = Nominatim(user_agent="ny_explorer")

for i, address in enumerate(neighborhoods):
    location = geolocator.geocode(address + ', WA')
    if(pd.isnull(location) == False):
        seattle_neighborhoods.loc[i] = [address, location.latitude, location.longitude]

seattle_neighborhoods.head()
# Out:
#                Neighborhood   Latitude   Longitude
# 0             North Seattle  47.660773 -122.291497
# 1                 Broadview  47.722320 -122.360407
# 2               Bitter Lake  47.726236 -122.348764
# 3  North Beach / Blue Ridge  47.700278 -122.396189
# 4                Crown Hill  47.694715 -122.371459

# %% [markdown]
# Use Foursquare APIs

# %%
CLIENT_ID = 'O1WQKL3EGFHCYD35S0Y4AAAZEBTSFF5KIUXSXEN5H2BIAZ3Y' # your Foursquare ID
CLIENT_SECRET = '0WZXE0XAFETCTVMLS14MAVKMTYDWXGWBGJF3TWGEAC4DTK0J' # your Foursquare Secret
VERSION = '20190425' # Foursquare API version

# these value can be changed accordingly
LIMIT = 50
radius = 500

# %% [markdown]
# ### Get Categories name and Id with the Foursquare APIs
# ##### We only need Food catigories. Get relevant part of JSON and transform it into a pandas dataframe

# %%
result = requests.get("https://api.foursquare.com/v2/venues/categories?client_id={}&client_secret={}&v={}".format(
    CLIENT_ID, 
    CLIENT_SECRET,
    VERSION)).json()
    
df_foodcatigories = pd.DataFrame(columns=['CategoryName','CategoryId'])
foodCategories = [r for r in result['response']['categories'] if r['name']=='Food'] 

for i, c in enumerate(foodCategories[0]['categories']):
    df_foodcatigories.loc[i] = [c['name'], c['id']]
    
df_foodcatigories.head()
# Out:
#             CategoryName                CategoryId
# 0      Afghan Restaurant  503288ae91d4c4b30a586d67
# 1     African Restaurant  4bf58dd8d48988d1c8941735
# 2    American Restaurant  4bf58dd8d48988d14e941735
# 3       Asian Restaurant  4bf58dd8d48988d142941735
# 4  Australian Restaurant  4bf58dd8d48988d169941735

# %%
df_foodcatigories.shape[0]
# Out:
# 91

# %% [markdown]
# <h2>Explore restaurants in the Seattle neighborhood</h2>
# - Create a function to return the name, style, and address of selected cuisine restaurants in major Seattle neighborhoods.
# - Create a function to return the first 50 restaurants with name, cuisine style, and address in a given Seattle neighborhood.

# %%
def CuisineRestaurantinArea(client_id, client_secret, version, lat, lon, radius, categoryId):
    url = "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&intent=browse&radius={}&categoryId={}".format(
        client_id, 
        client_secret,
        version,
        lat,
        lon,
        radius,
        categoryId)
    #print(url)
    foodvenues = requests.get(url).json()   
    #print(foodvenues)
    df = pd.DataFrame(columns = ['Name', 'Style', 'Address'])
    idx = 0
    if len(foodvenues['response']['venues']) > 0:     
        for v in foodvenues['response']['venues']:
            address = v['location']['formattedAddress']
            df.loc[idx] = [v['name'], v['categories'][0]['name'], address]
            idx += 1
    return df

# %% [markdown]
# #### Get the 'major' Seattle neighborhoods that name contain word Seattle

# %%
df_seattle = seattle_neighborhoods[seattle_neighborhoods['Neighborhood'].apply(lambda tag: 'Seattle' in tag)].reset_index(drop=True)

df_seattle
# Out:
#                 Neighborhood   Latitude   Longitude
# 0              North Seattle  47.660773 -122.291497
# 1            Central Seattle  47.612694 -122.303205
# 2  South Lake Union, Seattle  47.623161 -122.338382
# 3           Cascade, Seattle  47.620241 -122.333318
# 4               West Seattle  47.570932 -122.386517

# %% [markdown]
# <h3>Find the restaurants of selected cuisine in the Seattle neighborhoods</h3>
#
# Query with Foursqaure API and return restaurants for a specified cuisine in the neighborhoods, which have 'Seattle' in name.

# %%
def GetCuisineInformation(cuisine_category):      
    c_id = cuisine_category['CategoryId'].values[0]
    seattle_cuisines_dict = {}
    restaurant_count = pd.DataFrame(columns=['Name', 'Count'])
    for i, n in df_seattle.iterrows():
        cuisines = CuisineRestaurantinArea(CLIENT_ID, CLIENT_SECRET, VERSION, n['Latitude'], n['Longitude'], radius, c_id)
        if cuisines.shape[0] == 0:
            continue

        seattle_cuisines_dict[n['Neighborhood']] = cuisines
        restaurant_count.loc[i] = [n['Neighborhood'], cuisines.shape[0]]
        
    restaurant_count.sort_values(by='Count', inplace=True, ascending=False)
    for i, c in restaurant_count.iterrows():
        df = seattle_cuisines_dict[c['Name']]
        yield (c['Name'], df)

# %% [markdown]
# #### Display cuisine restaurants for the Seattle neighborhoods (with 'Seattle' in name) with the neighborhood sorted by number of the cuisine found ascendingly.

# %%
# looping to allow user select cuisine. if 'Q' is enter, stop
while True:
    cuisine_prefix = input('Cuisine(i.e. Asian or Italian) or Q to stop:')
    if cuisine_prefix == 'Q':
        break
    else:
        cuisine_category = df_foodcatigories[df_foodcatigories['CategoryName'].apply(lambda tag: tag.startswith(cuisine_prefix))]
        if cuisine_category.shape[0] == 0:
            print("Not find cuisine:{} please try again!".format(cuisine_prefix))
            continue
            
        for (n, df) in GetCuisineInformation(cuisine_category):
            print('\033[1m' + n  + '\033[0m')
            display(df)
            print('')
# Out:
# Cuisine(i.e. Asian or Italian) or Q to stop:Asian
# Cascade, Seattle
#                         Name                  Style  \
# 0                 Ba Bar SLU  Vietnamese Restaurant
# 1                    Phở Bac  Vietnamese Restaurant
# 2               Kigo Kitchen       Asian Restaurant
# 3                     Teinei    Japanese Restaurant
# 4      Vinason Pho And Grill  Vietnamese Restaurant
# 5         Thai Thani Kitchen        Thai Restaurant
# 6                  Mio Sushi       Sushi Restaurant
# 7               Mala & Satay  Vietnamese Restaurant
# 8            Midori Teriyaki    Japanese Restaurant
# 9                 ON THE FLY       Asian Restaurant
# 10              Kigo Kitchen       Asian Restaurant
# 11         Yumbit Food Truck             Food Truck
# 12  Kaosamai Thai at Ducky's             Food Truck
# 13                 Yummy Box             Food Truck
# 14      Stop N Shop Poke Bar             Poke Place
# 15          Box Nature Sushi             Food Truck
# 16             Its Bao Time!             Food Truck
# 17           Six Coins – SLU             Food Truck
#
#                                               Address
# 0   [500 Terry Ave N (Republican), Seattle, WA 981...
# 1   [1809 Minor Ave (at 8th Ave.), Seattle, WA 981...
# 2   [1730 Minor Ave, Seattle, WA 98101, United Sta...
# 3   [1256 Republican St (Pontius Ave N and Yale Av...
# 4   [2134 Westlake Ave (9th Ave), Seattle, WA 9812...
# 5   [201 Boren Ave N (John), Seattle, WA 98109, Un...
# 6   [120 Westlake Ave N, Seattle, WA 98109, United...
# 7                  [Seattle, WA 98109, United States]
# 8   [1120 Howell St (at Minor), Seattle, WA 98101,...
# 9   [950 Thomas Street, Seattle, WA 98119, United ...
# 10  [210 Westlake Ave N, Seattle, WA 98109, United...
# 11                        [Washington, United States]
# 12  [Terry Ave (btwn Denny Way & John St), Seattle...
# 13                        [Washington, United States]
# 14  [2121 Terry Ave Ste 104, Seattle, WA 98121, Un...
# 15  [Boren Ave (between Republican & Harison), Sea...
# 16                       [Seattle, WA, United States]
# 17  [Stewart St. (John St.), Seattle, WA 98109, Un...
# South Lake Union, Seattle
#                     Name                      Style  \
# 0             Ba Bar SLU      Vietnamese Restaurant
# 1   Hurry Curry of Tokyo  Japanese Curry Restaurant
# 2              Revel SLU          Korean Restaurant
# 3     Thai Thani Kitchen            Thai Restaurant
# 4              Mio Sushi           Sushi Restaurant
# 5        Sizzle & Crunch      Vietnamese Restaurant
# 6           Mala & Satay      Vietnamese Restaurant
# 7             ON THE FLY           Asian Restaurant
# 8           Kigo Kitchen           Asian Restaurant
# 9              Yummy Box                 Food Truck
# 10   Hong Kong Fish Ball                 Food Stand
# 11      Box Nature Sushi                 Food Truck
# 12                   Toi            Thai Restaurant
# 13         Its Bao Time!                 Food Truck
# 14         Muay Thai Max            Thai Restaurant
#
#                                               Address
# 0   [500 Terry Ave N (Republican), Seattle, WA 981...
# 1   [825 Harrison St (8th Ave N), Seattle, WA 9810...
# 2   [513 Westlake Ave N, Seattle, WA 98109, United...
# 3   [201 Boren Ave N (John), Seattle, WA 98109, Un...
# 4   [120 Westlake Ave N, Seattle, WA 98109, United...
# 5   [500 9th Ave N Ste 150, Seattle, WA 98109, Uni...
# 6                  [Seattle, WA 98109, United States]
# 7   [950 Thomas Street, Seattle, WA 98119, United ...
# 8   [210 Westlake Ave N, Seattle, WA 98109, United...
# 9                         [Washington, United States]
# 10                 [Seattle, WA 98109, United States]
# 11  [Boren Ave (between Republican & Harison), Sea...
# 12   [1904 4th Ave, Seattle, WA 98101, United States]
# 13                       [Seattle, WA, United States]
# 14   [1106 8th Ave, Seattle, WA 98101, United States]
# North Seattle
#                             Name                Style  \
# 0            Marlai Thai Cuisine      Thai Restaurant
# 1  Toshi's Teriyaki The Original  Japanese Restaurant
# 2                        Sunrice     Asian Restaurant
# 3                  China Village   Chinese Restaurant
#
#                                              Address
# 0  [3719 NE 45th St, Seattle, WA 98105, United St...
# 1  [3715 NE 45th St, Seattle, WA 98105, United St...
# 2  [3513 NE 45th St, Seattle, WA 98105, United St...
# 3  [3224 NE 45th St, Seattle, WA 98105, United St...
# West Seattle
#        Name            Style  \
# 0  Srivilai  Thai Restaurant
#
#                                              Address
# 0  [3247 Califronia SW (SW Hinds), Seattle, WA 98...
# Cuisine(i.e. Asian or Italian) or Q to stop:Q

# %% [markdown]
# We can find all of the seattle neighborhoods in dataframe: seattle_neighborhoods

# %%
seattle_neighborhoods.head(6)
# Out:
#                Neighborhood   Latitude   Longitude
# 0             North Seattle  47.660773 -122.291497
# 1                 Broadview  47.722320 -122.360407
# 2               Bitter Lake  47.726236 -122.348764
# 3  North Beach / Blue Ridge  47.700278 -122.396189
# 4                Crown Hill  47.694715 -122.371459
# 5                 Greenwood  47.690981 -122.354877

# %% [markdown]
# <h3>Find the first 50 Restaurants in a given Seattle Neighborhood</h3>
# This can be scaled up to return more or less by change limit vlaue.

# %% [markdown]
# <h4>Explore limited (50) number of all kind restaurants in the Seattle neighborhood</h4>
#
# Create a function to return the name, cuisine, and address of the restaurants in that neighborhood.

# %%
def GetAllRestaurantinNeighborhood(client_id, client_secret, version, lat, lon, radius, limit, c_id):
    url = "https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&intent=browse&radius={}&limit={}&categoryId={}".format(
        client_id, 
        client_secret,
        version,
        lat,
        lon,
        radius,
        limit,
        c_id)
    foodvenues = requests.get(url).json()
    df = pd.DataFrame(columns = ['Name', 'Style', 'Address'])
    idx = 0
    if len(foodvenues['response']['venues']) > 0:     
        for v in foodvenues['response']['venues']:
            address = v['location']['formattedAddress']
            df.loc[idx] = [v['name'], v['categories'][0]['name'], address]
            idx += 1
    return df

# %%
def GetNeighborhoodRestaurants(categoryId, neighborhoodName):
    n = seattle_neighborhoods[seattle_neighborhoods["Neighborhood"] == neighborhoodName].reset_index(drop=True)

    df = GetAllRestaurantinNeighborhood(CLIENT_ID, CLIENT_SECRET, VERSION, n.loc[0]['Latitude'], n.loc[0]['Longitude'], radius, LIMIT,categoryId)
    return df

# %% [markdown]
# ####  Display first 50 (all kind of cuisines) restaurants for the selected Seattle neighborhood.
# Looping to allow user select the neighborhoods repeatly, till enter 'Q' that end the loop.

# %%
# looping to allow user select seattle neighborhoods. if 'Q' is enter, stop
while True:
    neighborhood = input('Seattle Neiborhood Name or Q to stop:')
    if neighborhood == 'Q':
        break
    else:
        n_names = seattle_neighborhoods[seattle_neighborhoods['Neighborhood'].apply(lambda tag: tag == neighborhood)]
        if n_names.shape[0] == 0:
            print("Not find Neighborhood: {} please try again!".format(neighborhood))
            continue
        # food category id    
        food_categoryId = '4d4b7105d754a06374d81259'    
        df = GetNeighborhoodRestaurants(food_categoryId,neighborhood)
        print('\033[1m' + neighborhood  + '\033[0m')
        display(df)
        print('')
# Out:
# Seattle Neiborhood Name or Q to stop:reenwood
# Not find Neighborhood: reenwood please try again!
# Seattle Neiborhood Name or Q to stop:Greenwood
#   Neighborhood   Latitude   Longitude
# 0    Greenwood  47.690981 -122.354877
# Greenwood
#                          Name                          Style  \
# 0            North Star Diner                          Diner
# 1            Coyle's Bakeshop                         Bakery
# 2       FlintCreek Cattle Co.                     Steakhouse
# 3                   The Lodge                      Gastropub
# 4    Fred Meyer Breakfast Bar                 Breakfast Spot
# 5                    Gorditos             Mexican Restaurant
# 6   Chaco Canyon Organic Café  Vegetarian / Vegan Restaurant
# 7                   Chef King             Chinese Restaurant
# 8         Valhalla Sandwiches                 Sandwich Place
# 9   Monkey Grind Espresso Bar                    Coffee Shop
# 10              Diva Espresso                    Coffee Shop
# 11           Razzi's Pizzeria                    Pizza Place
# 12                Hummus Cafe      Middle Eastern Restaurant
# 13           Taqueria Tequila             Mexican Restaurant
# 14          The Olive & Grape       Mediterranean Restaurant
# 15        Chocolati Greenwood                    Coffee Shop
# 16                 Gainsbourg              French Restaurant
# 17  Istanbul Kebap Restaurant             Turkish Restaurant
# 18            Urban Pizza VIP                    Pizza Place
# 19                  Starbucks                    Coffee Shop
# 20                  Satay Bar                Thai Restaurant
# 21                La Conasupo             Mexican Restaurant
# 22            Stage Door Cafe                           Café
#
#                                               Address
# 0   [8700 Greenwood Ave N (N 87th Street), Seattle...
# 1   [8300 Greenwood Ave N (N 83rd St), Seattle, WA...
# 2   [8421 Greenwood Ave N (85TH ST), Seattle, WA 9...
# 3   [8501 Greenwood Ave N (N 85th Street), Seattle...
# 4           [85th Street, Seattle, WA, United States]
# 5   [213 N 85th St, Seattle, WA 98103, United States]
# 6   [8404 Greenwood Ave N (85th), Seattle, WA 9810...
# 7                  [Seattle, WA 98103, United States]
# 8   [8202 Greenwood Ave N (N. 82nd), Seattle, WA 9...
# 9   [518 N 85th St (at Evanston), Seattle, WA 9810...
# 10  [7916 Greenwood Ave N (at N 80th St), Seattle,...
# 11  [8523 Greenwood Ave N (at 85th St), Seattle, W...
# 12  [8420 Greenwood Ave N, Seattle, WA 98103, Seat...
# 13  [301 NW 85th St (3rd Ave. NW), Seattle, WA 981...
# 14  [8516 Greenwood Ave N (at NW 85th St), Seattle...
# 15  [8319 Greenwood Ave N (at N 84th St), Seattle,...
# 16  [8550 Greenwood Ave N (at N 85th St), Seattle,...
# 17  [8317 Greenwood Ave N (at 84th), Seattle, WA 9...
# 18                 [Seattle, WA 98117, United States]
# 19  [100 NW 85th St, Seattle, WA 98117, United Sta...
# 20                 [Seattle, WA 98103, United States]
# 21  [8532 Greenwood Ave N, Seattle, WA 98103, Unit...
# 22  [208 N 85th St (Greenwood), Seattle, WA 98103,...
# Seattle Neiborhood Name or Q to stop:Broadview
#   Neighborhood  Latitude   Longitude
# 0    Broadview  47.72232 -122.360407
# Broadview
#                       Name             Style  \
# 0       Ichi Roll Teriyaki  Sushi Restaurant
# 1           Domino's Pizza       Pizza Place
# 2               Chada Thai   Thai Restaurant
# 3  Brother John's Pizzeria              Food
#
#                                              Address
# 0  [326 N 125th St, Seattle, WA 98133, United Sta...
# 1  [302 N 125th St, Seattle, WA 98133, United Sta...
# 2  [308 N 125th St, Seattle, WA 98133, United Sta...
# 3  [12427 Greenwood Ave N, Seattle, WA 98133, Uni...
# Seattle Neiborhood Name or Q to stop:Bitter Lake
#   Neighborhood   Latitude   Longitude
# 0  Bitter Lake  47.726236 -122.348764
# Bitter Lake
#                                   Name                        Style  \
# 0                          Chick-fil-A         Fast Food Restaurant
# 1     Green Leaf Vietnamese Restaurant        Vietnamese Restaurant
# 2                           HK Dim Sum           Dim Sum Restaurant
# 3                            Starbucks                  Coffee Shop
# 4                            Rain Cafe                         Café
# 5                         Qian Noodles                 Noodle House
# 6             Pop Pop Thai Street Food              Thai Restaurant
# 7                               Ivar's           Seafood Restaurant
# 8                          kiki bakery                       Bakery
# 9                          Burger King         Fast Food Restaurant
# 10                         Master Chef           Chinese Restaurant
# 11         Nrgize - Temporarily Closed                Smoothie Shop
# 12     Buerjia Chinese Sauerkraut Fish           Chinese Restaurant
# 13                       Style Hot Pot            Hotpot Restaurant
# 14    chinese sauerkraut fish 不二家老坛酸菜鱼           Chinese Restaurant
# 15                       Gourmet Latte                  Coffee Shop
# 16                             JoyFish          Szechuan Restaurant
# 17                   No.9 Alley Hotpot           Chinese Restaurant
# 18                      European Foods  Eastern European Restaurant
# 19                                 KFC          Fried Chicken Joint
# 20                      Tully's Coffee                  Coffee Shop
# 21                       Aurora Donuts                   Donut Shop
# 22              Yamashiro Sushi Broker                         Food
# 23                          Bubbleland                  Coffee Shop
# 24       Asian 1 Healthy Asian Cuisine             Asian Restaurant
# 25                     For Your Health                         Food
# 26        L' Forno Pizza, Pita & Sweet               Sandwich Place
# 27               Emerald City Smoothie                    Juice Bar
# 28                        Jimmy John's               Sandwich Place
# 29                             L'forno                   Restaurant
# 30               Prodiso Panda Kitchen                         Food
# 31                      Baskin-Robbins               Ice Cream Shop
# 32  Warabi Japanese Restaurant and Bar          Japanese Restaurant
# 33               green leaf restaurant        Vietnamese Restaurant
# 34                    Teriyaki and Pho        Vietnamese Restaurant
# 35                          UDV Dining                   Restaurant
# 36                            Hey Ming           Chinese Restaurant
#
#                                               Address
# 0   [12801 Aurora Ave N (N 128th St), Seattle, WA ...
# 1   [13200 Aurora Ave N, Seattle, WA 98133, United...
# 2   [13200 Aurora Ave N Apt F, Seattle, WA 98133, ...
# 3   [13025 Aurora Ave N, Seattle, WA 98133, United...
# 4   [13200 Aurora Ave N, Suite C, Seattle, WA 9813...
# 5   [13510 Aurora Ave N, Seattle, WA 98133, United...
# 6   [13242 Aurora Ave N, Seattle, WA 98133, United...
# 7   [13448 Aurora Ave N (at N 135th St.), Seattle,...
# 8   [13200 Aurora Ave N Apt E (130th), Seattle, WA...
# 9   [13241 Aurora Ave N, Seattle, WA 98133, United...
# 10  [13200 Aurora Ave N Apt D, Seattle, WA 98133, ...
# 11  [13244 Aurora Ave N, Seattle, WA 98133, United...
# 12  [13200 Aurora Ave N, Seattle, WA 98133, United...
# 13  [930 N 130th St, Seattle, WA 98133, United Sta...
# 14                 [Seattle, WA 98133, United States]
# 15  [13279 Aurora Ave N (At N 135th St), Seattle, ...
# 16  [13231 Aurora Ave N, Seattle, WA 98133, United...
# 17  [930 N 130th St, Seattle, WA 98133, United Sta...
# 18  [13520 Aurora Ave N (Btwn: 135th St & 137th St...
# 19  [13450 Aurora Ave N, Seattle, WA 98133, United...
# 20  [13050 Aurora Ave N (inside Albertson's), Seat...
# 21  [13201 Aurora Ave N #C (at N 130th St), Seattl...
# 22  [13754 Aurora Ave N, Seattle, WA 98133, United...
# 23  [13754 Aurora Ave N, Seattle, WA 98133, United...
# 24  [13231 Aurora Ave N, Seattle, WA 98133, United...
# 25  [13500 Linden Ave N, Seattle, WA 98133, United...
# 26  [13000 Linden Ave N, Seattle, WA 98133, United...
# 27  [13244 Aurora Ave N (in LA Fitness), Seattle, ...
# 28  [13242 Aurora Ave N (N. 135th St), Seattle, WA...
# 29  [13000 Linden Ave N #106, Seattle, WA 98133, U...
# 30  [13520 Aurora Ave N, Seattle, WA 98133, United...
# 31  [13201 Aurora Ave N, Seattle, WA 98133, United...
# 32  [13754 Aurora Ave N, Seattle, WA 98133, United...
# 33  [13200 Aurora Ave N, Seattle, WA 98133, United...
# 34  [13027 Aurora Ave N, Seattle, WA 98133, United...
# 35  [13500 Linden Ave N, Seattle, WA 98133, United...
# 36  [13231 Aurora Ave N, Seattle, WA 98133, United...
# Seattle Neiborhood Name or Q to stop:Q

# %% [markdown]
# <h2>Conclusion</h2>
#
# - This application let the customers chose the cuisine information of then return the cuisine restaurants in the major Seattle neighhoods, which have 'Seattle' in name, grouping by the neighborhood that ordered by the most cuisine restaurants found. It can be easily scaled to all neighborhoods in Seattle or other areas.
#
# - The application let the customers chose a Seattle neighborhood then return the information of the first 50 restaurants found in that neighborhood. It can be easily scaled to return all restaurants in the chosen neighborhood.
